# %% [markdown]
# 1. Declarar librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
#import pandas_profiling as pp
import seaborn as sns
import warnings
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.cluster import KMeans

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# 2. Cargar los datos

# %%
df =pd.read_excel('Empresas_Reactiva_Perú.xlsx')
df = pd.DataFrame(df)
df.head(n=10)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71553 entries, 0 to 71552
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RUC              71553 non-null  float64
#  1   NOMBRE_EMPRESA   71553 non-null  object
#  2   SECTOR           71553 non-null  object
#  3   BANCO            71553 non-null  object
#  4   MONTO_PRESTAMO   71553 non-null  float64
#  5   FLG_1MM          71553 non-null  int64
#  6   MONTO_COBERTURA  71553 non-null  float64
#  7   DEPARTAMENTO     71553 non-null  object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 4.4+ MB

# %%
df.head(3)
# Out:
#             RUC     NOMBRE_EMPRESA  \
# 0  2.052055e+10       1 ONE S.A.C.
# 1  2.054319e+10  1000 MILLAS SAC
# 2  2.037972e+10   100PRE FELIZ SAC
#
#                                        SECTOR            BANCO  \
# 0                                    COMERCIO          CRÉDITO
# 1                                    COMERCIO          CRÉDITO
# 2  AGRICULTUR, GANADERIA, CAZA Y SILVICULTURA  BANCO BBVA PERU
#
#    MONTO_PRESTAMO  FLG_1MM  MONTO_COBERTURA DEPARTAMENTO
# 0       1894383.0        1        1704944.7         LIMA
# 1        300570.0        0         270513.0         LIMA
# 2       1370000.0        1        1233000.0         LIMA

# %%
df.shape
# Out:
# (71553, 8)

# %%
df1 = pd.read_excel('Income.xlsx')
df1 = pd.DataFrame(df1)
df1.head(n=10)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71556 entries, 0 to 71555
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RUC     71553 non-null  float64
#  1   INCOME  71553 non-null  float64
# dtypes: float64(2)
# memory usage: 1.1 MB

# %%
df1.head(3)
# Out:
#             RUC        INCOME
# 0  2.052055e+10  5.903929e+08
# 1  2.054319e+10  9.367398e+07
# 2  2.037972e+10  1.701463e+07

# %%
df2 = pd.merge(df, df1, on='RUC')

# %%
df2.head(3)
# Out:
#             RUC     NOMBRE_EMPRESA  \
# 0  2.052055e+10       1 ONE S.A.C.
# 1  2.054319e+10  1000 MILLAS SAC
# 2  2.037972e+10   100PRE FELIZ SAC
#
#                                        SECTOR            BANCO  \
# 0                                    COMERCIO          CRÉDITO
# 1                                    COMERCIO          CRÉDITO
# 2  AGRICULTUR, GANADERIA, CAZA Y SILVICULTURA  BANCO BBVA PERU
#
#    MONTO_PRESTAMO  FLG_1MM  MONTO_COBERTURA DEPARTAMENTO        INCOME
# 0       1894383.0        1        1704944.7         LIMA  5.903929e+08
# 1        300570.0        0         270513.0         LIMA  9.367398e+07
# 2       1370000.0        1        1233000.0         LIMA  1.701463e+07

# %% [markdown]
# 3. Exploración de datos

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df2.describe()
# Out:
#                  RUC  MONTO_PRESTAMO  FLG_1MM  MONTO_COBERTURA        INCOME
# count       71555.00        71555.00 71555.00         71555.00      71555.00
# mean  18139283309.37       345873.84     0.07        302322.29   50467597.53
# std    4317413281.14      1144352.80     0.25        939468.10  187540502.83
# min   10000006209.00          500.00     0.00           490.00       1645.63
# 25%   20108847754.00        20330.50     0.00         19923.89    3750018.65
# 50%   20512027084.00        55000.00     0.00         52250.00   11071589.86
# 75%   20561283580.00       176434.00     0.00        167612.30   33664411.68
# max   20606001419.00     10000000.00     1.00       8000000.00 7373652651.55

# %%
#CREAMOS EL % DE COBERTURA:

df2['PORCENTAJE_COBERTURA'] = df2['MONTO_COBERTURA'] / df2['MONTO_PRESTAMO']

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71555 entries, 0 to 71554
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   RUC                   71555 non-null  float64
#  1   NOMBRE_EMPRESA        71555 non-null  object
#  2   SECTOR                71555 non-null  object
#  3   BANCO                 71555 non-null  object
#  4   MONTO_PRESTAMO        71555 non-null  float64
#  5   FLG_1MM               71555 non-null  int64
#  6   MONTO_COBERTURA       71555 non-null  float64
#  7   DEPARTAMENTO          71555 non-null  object
#  8   INCOME                71555 non-null  float64
#  9   PORCENTAJE_COBERTURA  71555 non-null  float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
df2.head(3)
# Out:
#              RUC     NOMBRE_EMPRESA  \
# 0 20520549740.00       1 ONE S.A.C.
# 1 20543190617.00  1000 MILLAS SAC
# 2 20379719440.00   100PRE FELIZ SAC
#
#                                        SECTOR            BANCO  \
# 0                                    COMERCIO          CRÉDITO
# 1                                    COMERCIO          CRÉDITO
# 2  AGRICULTUR, GANADERIA, CAZA Y SILVICULTURA  BANCO BBVA PERU
#
#    MONTO_PRESTAMO  FLG_1MM  MONTO_COBERTURA DEPARTAMENTO       INCOME  \
# 0      1894383.00        1       1704944.70         LIMA 590392875.16
# 1       300570.00        0        270513.00         LIMA  93673975.37
# 2      1370000.00        1       1233000.00         LIMA  17014629.00
#
#    PORCENTAJE_COBERTURA
# 0                  0.90
# 1                  0.90
# 2                  0.90

# %%
corr = df2[['MONTO_PRESTAMO','MONTO_COBERTURA','INCOME','PORCENTAJE_COBERTURA']].corr().round(4)
corr
# Out:
#                       MONTO_PRESTAMO  MONTO_COBERTURA  INCOME  \
# MONTO_PRESTAMO                  1.00             1.00    0.56
# MONTO_COBERTURA                 1.00             1.00    0.57
# INCOME                          0.56             0.57    1.00
# PORCENTAJE_COBERTURA           -0.74            -0.74   -0.48
#
#                       PORCENTAJE_COBERTURA
# MONTO_PRESTAMO                       -0.74
# MONTO_COBERTURA                      -0.74
# INCOME                               -0.48
# PORCENTAJE_COBERTURA                  1.00

# %%
X=np.array(df2[['PORCENTAJE_COBERTURA','MONTO_PRESTAMO','INCOME']])
X.shape
# Out:
# (71555, 3)

# %% [markdown]
# 4. Modelado

# %%
Nc = range(1, 20)
kmeans = [KMeans(n_clusters=i) for i in Nc]
kmeans
score = [kmeans[i].fit(X).score(X) for i in range(len(kmeans))]
score
plt.plot(Nc,score)
plt.xlabel('Número de Grupos')
plt.ylabel('Puntaje')
plt.title('Curva de Elbow')
plt.show()

# %%
num_clusters = 4

# %%
data=df2[['PORCENTAJE_COBERTURA','MONTO_PRESTAMO','INCOME']]

# %%
#Segmentación de KMEANS

kmeans = KMeans(init='k-means++', n_clusters=num_clusters, n_init=10)
kmeans.fit(data)
# Out:
# KMeans(n_clusters=4, n_init=10)

# %%
def form_cluster(x,k):
    no_clusters = k
    model = KMeans(n_clusters=no_clusters,init='random')
    model.fit(x)
    labels = model.labels_
    print(labels)
    # Cacluate the silhouette score
    sh_score = silhouette_score(x,labels)
    return sh_score

# %%
prediction = kmeans.predict(data)

# %%
prediction
# Out:
# array([3, 0, 0, ..., 0, 3, 0], dtype=int32)

# %%
pronosseg = pd.DataFrame(prediction)

# %%
pronosseg.columns=['Segmento']

# %%
sns.pairplot(pd.concat([data,pronosseg],axis=1), hue="Segmento")

# %%
res1=pd.concat([data,pronosseg],axis=1).groupby(['Segmento']).mean()
res1.style.applymap(lambda x: 'background-color : yellow' if x>res1.iloc[0,0] else '')
# Out:
# <style type="text/css">
# #T_6f82e_row0_col1, #T_6f82e_row0_col2, #T_6f82e_row1_col1, #T_6f82e_row1_col2, #T_6f82e_row2_col1, #T_6f82e_row2_col2, #T_6f82e_row3_col1, #T_6f82e_row3_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_6f82e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f82e_level0_col0" class="col_heading level0 col0" >PORCENTAJE_COBERTURA</th>
#       <th id="T_6f82e_level0_col1" class="col_heading level0 col1" >MONTO_PRESTAMO</th>
#       <th id="T_6f82e_level0_col2" class="col_heading level0 col2" >INCOME</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Segmento</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f82e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f82e_row0_col0" class="data row0 col0" >0.954224</td>
#       <td id="T_6f82e_row0_col1" class="data row0 col1" >230219.192256</td>
#       <td id="T_6f82e_row0_col2" class="data row0 col2" >23427614.122556</td>
#     </tr>
#     <tr>
#       <th id="T_6f82e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6f82e_row1_col0" class="data row1 col0" >0.862363</td>
#       <td id="T_6f82e_row1_col1" class="data row1 col1" >5350686.172829</td>
#       <td id="T_6f82e_row1_col2" class="data row1 col2" >1321159188.787853</td>
#     </tr>
#     <tr>
#       <th id="T_6f82e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6f82e_row2_col0" class="data row2 col0" >0.803000</td>
#       <td id="T_6f82e_row2_col1" class="data row2 col1" >9180699.733750</td>
#       <td id="T_6f82e_row2_col2" class="data row2 col2" >3381509479.173045</td>
#     </tr>
#     <tr>
#       <th id="T_6f82e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6f82e_row3_col0" class="data row3 col0" >0.893907</td>
#       <td id="T_6f82e_row3_col1" class="data row3 col1" >1850980.269906</td>
#       <td id="T_6f82e_row3_col2" class="data row3 col2" >346892082.434581</td>
#     </tr>
#   </tbody>
# </table>

# %%
pronosseg.head()
# Out:
#    Segmento
# 0         3
# 1         0
# 2         0
# 3         0
# 4         0

# %%
data_final=pd.concat([df2,pronosseg],axis=1)

# %%
data_final.head()
# Out:
#              RUC                              NOMBRE_EMPRESA  \
# 0 20520549740.00                                1 ONE S.A.C.
# 1 20543190617.00                           1000 MILLAS SAC
# 2 20379719440.00                            100PRE FELIZ SAC
# 3 20602664091.00                                    1010 SAC
# 4 20601455375.00  105 EMERGENCIAS Y SOLUCIONES AQP E.I.R.L.
#
#                                        SECTOR            BANCO  \
# 0                                    COMERCIO          CRÉDITO
# 1                                    COMERCIO          CRÉDITO
# 2  AGRICULTUR, GANADERIA, CAZA Y SILVICULTURA  BANCO BBVA PERU
# 3                     INDUSTRIA MANUFACTURERA          CRÉDITO
# 4                                    COMERCIO          CRÉDITO
#
#    MONTO_PRESTAMO  FLG_1MM  MONTO_COBERTURA DEPARTAMENTO       INCOME  \
# 0      1894383.00        1       1704944.70         LIMA 590392875.16
# 1       300570.00        0        270513.00         LIMA  93673975.37
# 2      1370000.00        1       1233000.00         LIMA  17014629.00
# 3       600918.00        0        540826.20         LIMA 115386453.60
# 4         6350.00        0          6223.00     AREQUIPA   1979005.70
#
#    PORCENTAJE_COBERTURA  Segmento
# 0                  0.90         3
# 1                  0.90         0
# 2                  0.90         0
# 3                  0.90         0
# 4                  0.98         0

# %%
#EXPORTAR BASE
data_final.to_csv("resultados_test_2.csv",index=False)
